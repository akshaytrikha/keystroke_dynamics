# %% [markdown]
# # Required Imports and Setup

# %%
import csv
import pandas as pd
import numpy as np 
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests
from matplotlib import pyplot as plt
import matplotlib.cm as cm

# different imports for different versions of scikit-learn
try: 
    from sklearn.model_selection import cross_val_score 
except ImportError:
    try:
        from sklearn.cross_validation import cross_val_score
    except:
        print("No cross_val_score!")
        
# read typing data into pandas dataframe
# df = pd.read_csv("new_typing_data.csv", error_bad_lines=False)

# %% [markdown]
# # 1. Read typing data into a list

# %% [markdown]
# First read data from csv into a list

# %%
#
# readcsv is a starting point - it returns the rows from a standard csv file...
#
def readcsv( csv_file_name ):
    """ readcsv takes as
         + input:  csv_file_name, the name of a csv file
        and returns
         + output: a list of lists, each inner list is one row of the csv
           all data items are strings; empty cells are empty strings
    """
    try:
        csvfile = open( csv_file_name, newline='' )  # open for reading
        csvrows = csv.reader( csvfile )              # creates a csvrows object

        all_rows = []                                # we need to read the csv file
        for row in csvrows:                          # into our own Python data structure
            all_rows.append( row )                   # adds only the word to our list

        del csvrows                                  # acknowledge csvrows is gone!
        csvfile.close()                              # and close the file
        return all_rows                              # return the list of lists

    except FileNotFoundError as e:
        print("File not found: ", e)
        return []
    
akshay_data = readcsv("akshay.csv")

mummy_data = readcsv("mummy.csv")

test_data = readcsv("test.csv")[1]

# %% [markdown]
# Clean data so that it correctly starts with the "." character and doesn't include the "esc" character at the end

# %%
for i in range(len(akshay_data)):
    akshay_data[i] = akshay_data[i][3:-1]
    
for i in range(len(mummy_data)):
    mummy_data[i] = mummy_data[i][3:-1]
    
test_data = test_data[i][3:-1]

# %% [markdown]
# Let's see what the first 2 rows of Akshay's and Mummy's data look like

# %%
print("first 2 rows of akshay's data")
print(akshay_data[0], "\n")
print(akshay_data[1], "\n")

print("first 2 rows of mummy's data")
print(mummy_data[0], "\n")
print(mummy_data[1], "\n")
# Out:
# first 2 rows of akshay's data
# ["('.', 6.011002074, 'pressed')", "('.', 6.123425249, 'released')", "('t', 6.210437133, 'pressed')", "('t', 6.282306537, 'released')", "('i', 6.290148006, 'pressed')", "('i', 6.358390612, 'released')", "('e', 6.376343242, 'pressed')", "('e', 6.444386616, 'released')", "('5', 6.568501488, 'pressed')", "('5', 6.640304912, 'released')", "('Key.caps_lock', 6.848932655, 'pressed')", "('Key.caps_lock', 6.848944598, 'released')", "('R', 6.930270748, 'pressed')", "('Key.caps_lock', 6.989199045, 'pressed')", "('Key.caps_lock', 6.989210938, 'released')", "('r', 6.993649665, 'released')", "('o', 7.171154254, 'pressed')", "('o', 7.27922604, 'released')", "('a', 7.291250716, 'pressed')", "('a', 7.367345513, 'released')", "('n', 7.441349145, 'pressed')", "('l', 7.521346095, 'pressed')", "('n', 7.545366845, 'released')", "('e', 7.605384269, 'pressed')", "('l', 7.623357665, 'released')", "('e', 7.669298627, 'released')"]
#
# ["('.', 8.38986342, 'pressed')", "('.', 8.490285249, 'released')", "('t', 8.575306964, 'pressed')", "('t', 8.651273396, 'released')", "('i', 8.673271067, 'pressed')", "('i', 8.733186876, 'released')", "('e', 8.749213149, 'pressed')", "('e', 8.825263146, 'released')", "('5', 9.168222791, 'pressed')", "('5', 9.240097638, 'released')", "('Key.caps_lock', 9.485157417, 'pressed')", "('Key.caps_lock', 9.485164737, 'released')", "('R', 9.575046827, 'pressed')", "('Key.caps_lock', 9.662364231, 'pressed')", "('Key.caps_lock', 9.662376271, 'released')", "('r', 9.662669362, 'released')", "('o', 9.817902213, 'pressed')", "('a', 9.874697478, 'pressed')", "('o', 9.892880675, 'released')", "('a', 9.970176715, 'released')", "('n', 10.005251732, 'pressed')", "('l', 10.085114466, 'pressed')", "('n', 10.108561727, 'released')", "('l', 10.177101876, 'released')", "('e', 10.185113746, 'pressed')", "('e', 10.265192567, 'released')"]
#
# first 2 rows of mummy's data
# ["('.', 6.536593982, 'pressed')", "('.', 6.612855908, 'released')", "('t', 7.002701152, 'pressed')", "('t', 7.070716271, 'released')", "('i', 7.277856723, 'pressed')", "('i', 7.337695679, 'released')", "('e', 7.551730469, 'pressed')", "('e', 7.611777078, 'released')", "('5', 7.927725021, 'pressed')", "('5', 7.991631451, 'released')", "('Key.caps_lock', 8.414508413, 'pressed')", "('Key.caps_lock', 8.414522355, 'released')", "('R', 8.646699465, 'pressed')", "('R', 8.714678449, 'released')", "('Key.caps_lock', 8.896534197, 'pressed')", "('Key.caps_lock', 8.896544589, 'released')", "('o', 9.152520717, 'pressed')", "('o', 9.224591091, 'released')", "('a', 9.354570872, 'pressed')", "('a', 9.434536645, 'released')", "('n', 9.50644263, 'pressed')", "('n', 9.57849377, 'released')", "('l', 9.804507909, 'pressed')", "('l', 9.868535319, 'released')", "('e', 10.057611735, 'pressed')", "('e', 10.133560761, 'released')"]
#
# ["('.', 6.092324042, 'pressed')", "('.', 6.15642625, 'released')", "('t', 6.47641521, 'pressed')", "('t', 6.54049901, 'released')", "('i', 6.765585308, 'pressed')", "('i', 6.821546276, 'released')", "('e', 7.074256489, 'pressed')", "('e', 7.134579437, 'released')", "('5', 7.383349306, 'pressed')", "('5', 7.443477362, 'released')", "('Key.caps_lock', 7.888860038, 'pressed')", "('Key.caps_lock', 7.88887346, 'released')", "('R', 8.133356398, 'pressed')", "('R', 8.197825639, 'released')", "('Key.caps_lock', 8.342391729, 'pressed')", "('Key.caps_lock', 8.342405558, 'released')", "('o', 8.670810783, 'pressed')", "('o', 8.743458353, 'released')", "('a', 8.903156706, 'pressed')", "('a', 8.987345835, 'released')", "('n', 9.096474711, 'pressed')", "('n', 9.164322032, 'released')", "('l', 9.339459384, 'pressed')", "('l', 9.403295951, 'released')", "('e', 9.527219488, 'pressed')", "('e', 9.599263969, 'released')"]

# %% [markdown]
# Visualise the order in which the keys were pressed and released for the first 3 rows of both datasets

# %%
stringlist = []

stringlist += ["akshay's data"]

for i in range(3):
    stringlist += [[akshay_data[i][x][2] for x in range(len(akshay_data[i]))]]

stringlist += [""]
stringlist += ["mummy's data"]

for i in range(3):
    stringlist += [[akshay_data[i][x][2] for x in range(len(mummy_data[i]))]]

for row in stringlist:
    output = ""
    for character in row:
        output += character
    print(output)
# Out:
# akshay's data
# ..ttiiee55KKRKKrooaanlnele
# ..ttiiee55KKRKKroaoanlnlee
# ..ttiiee55KKRKKroaoanlnlee
#
# mummy's data
# ..ttiiee55KKRKKrooaanlnele
# ..ttiiee55KKRKKroaoanlnlee
# ..ttiiee55KKRKKroaoanlnlee

# %% [markdown]
# Convert str in rows to tuples

# %%
# first for akshay's data
new_data = []

for row in akshay_data:
    new_data_row = []
    for datapoint in row:
        new_data_row.append(eval(datapoint))
        print(datapoint)
    new_data.append(new_data_row)
    
akshay_data = new_data 

# then for mummy's data
new_data = []

for row in mummy_data:
    new_data_row = []
    for datapoint in row:
        new_data_row.append(eval(datapoint))
        print(datapoint)
    new_data.append(new_data_row)
    
mummy_data = new_data
# Out:
# ('.', 6.011002074, 'pressed')
# ('.', 6.123425249, 'released')
# ('t', 6.210437133, 'pressed')
# ('t', 6.282306537, 'released')
# ('i', 6.290148006, 'pressed')
# ('i', 6.358390612, 'released')
# ('e', 6.376343242, 'pressed')
# ('e', 6.444386616, 'released')
# ('5', 6.568501488, 'pressed')
# ('5', 6.640304912, 'released')
# ('Key.caps_lock', 6.848932655, 'pressed')
# ('Key.caps_lock', 6.848944598, 'released')
# ('R', 6.930270748, 'pressed')
# ('Key.caps_lock', 6.989199045, 'pressed')
# ('Key.caps_lock', 6.989210938, 'released')
# ('r', 6.993649665, 'released')
# ('o', 7.171154254, 'pressed')
# ('o', 7.27922604, 'released')
# ('a', 7.291250716, 'pressed')
# ('a', 7.367345513, 'released')
# ('n', 7.441349145, 'pressed')
# ('l', 7.521346095, 'pressed')
# ('n', 7.545366845, 'released')
# ('e', 7.605384269, 'pressed')
# ('l', 7.623357665, 'released')
# ('e', 7.669298627, 'released')
# ('.', 8.38986342, 'pressed')
# ('.', 8.490285249, 'released')
# ('t', 8.575306964, 'pressed')
# ('t', 8.651273396, 'released')
# ('i', 8.673271067, 'pressed')
# ('i', 8.733186876, 'released')
# ('e', 8.749213149, 'pressed')
# ('e', 8.825263146, 'released')
# ('5', 9.168222791, 'pressed')
# ('5', 9.240097638, 'released')
# ('Key.caps_lock', 9.485157417, 'pressed')
# ('Key.caps_lock', 9.485164737, 'released')
# ('R', 9.575046827, 'pressed')
# ('Key.caps_lock', 9.662364231, 'pressed')
# ('Key.caps_lock', 9.662376271, 'released')
# ('r', 9.662669362, 'released')
# ('o', 9.817902213, 'pressed')
# ('a', 9.874697478, 'pressed')
# ('o', 9.892880675, 'released')
# ('a', 9.970176715, 'released')
# ('n', 10.005251732, 'pressed')
# ('l', 10.085114466, 'pressed')
# ('n', 10.108561727, 'released')
# ('l', 10.177101876, 'released')
# ('e', 10.185113746, 'pressed')
# ('e', 10.265192567, 'released')
# ('.', 10.939570945, 'pressed')
# ('.', 11.036128041, 'released')
# ('t', 11.126088763, 'pressed')
# ('t', 11.201937899, 'released')
# ('i', 11.214059974, 'pressed')
# ('i', 11.270151352, 'released')
# ('e', 11.308126346, 'pressed')
# ('e', 11.372180124, 'released')
# ('5', 11.635128448, 'pressed')
# ('5', 11.703120939, 'released')
# ('Key.caps_lock', 11.922633535, 'pressed')
# ('Key.caps_lock', 11.922646431, 'released')
# ('R', 11.989133827, 'pressed')
# ('Key.caps_lock', 12.087871837, 'pressed')
# ('Key.caps_lock', 12.08788583, 'released')
# ('r', 12.088073499, 'released')
# ('o', 12.172132195, 'pressed')
# ('a', 12.264065269, 'pressed')
# ('o', 12.267940661, 'released')
# ('a', 12.360162328, 'released')
# ('n', 12.420651738, 'pressed')
# ('l', 12.481062185, 'pressed')
# ('n', 12.512580228, 'released')
# ('l', 12.580987824, 'released')
# ('e', 12.584930366, 'pressed')
# ('e', 12.649091624, 'released')
# ('.', 13.318962387, 'pressed')
# ('.', 13.423125168, 'released')
# ('t', 13.460004321, 'pressed')
# ('t', 13.532024457, 'released')
# ('i', 13.559893515, 'pressed')
# ('i', 13.620012901, 'released')
# ('e', 13.644954794, 'pressed')
# ('e', 13.71301458, 'released')
# ('5', 13.855960037, 'pressed')
# ('5', 13.931836037, 'released')
# ('Key.caps_lock', 14.143688095, 'pressed')
# ('Key.caps_lock', 14.143696783, 'released')
# ('R', 14.200354497, 'pressed')
# ('R', 14.264273401, 'released')
# ('Key.caps_lock', 14.271281684, 'pressed')
# ('Key.caps_lock', 14.271287917, 'released')
# ('o', 14.388961733, 'pressed')
# ('o', 14.456960777, 'released')
# ('a', 14.460893553, 'pressed')
# ('a', 14.556988773, 'released')
# ('n', 14.587137585, 'pressed')
# ('l', 14.666933137, 'pressed')
# ('n', 14.694717227, 'released')
# ('e', 14.750897147, 'pressed')
# ('l', 14.762491638, 'released')
# ('e', 14.834963225, 'released')
# ('.', 3.631960375, 'pressed')
# ('.', 3.724061902, 'released')
# ('t', 3.802854024, 'pressed')
# ('t', 3.879087354, 'released')
# ('i', 3.918093496, 'pressed')
# ('i', 3.974099664, 'released')
# ('e', 3.996091116, 'pressed')
# ('e', 4.068336953, 'released')
# ('5', 4.197929362, 'pressed')
# ('5', 4.269973215, 'released')
# ('Key.caps_lock', 4.470400299, 'pressed')
# ('Key.caps_lock', 4.470410054, 'released')
# ('R', 4.524887336, 'pressed')
# ('Key.caps_lock', 4.606905536, 'pressed')
# ('Key.caps_lock', 4.606917837, 'released')
# ('r', 4.616760176, 'released')
# ('o', 4.713016802, 'pressed')
# ('o', 4.792928244, 'released')
# ('a', 4.796831773, 'pressed')
# ('a', 4.885352739, 'released')
# ('n', 4.9199538, 'pressed')
# ('l', 5.000180024, 'pressed')
# ('n', 5.015886337, 'released')
# ('l', 5.07199747, 'released')
# ('e', 5.099273556, 'pressed')
# ('e', 5.155037183, 'released')
# ('.', 5.99537153, 'pressed')
# ('.', 6.086981998, 'released')
# ('t', 6.212874239, 'pressed')
# ('t', 6.296972977, 'released')
# ('i', 6.330861782, 'pressed')
# ('i', 6.398975273, 'released')
# ('e', 6.421000278, 'pressed')
# ('e', 6.497222325, 'released')
# ('5', 6.629726277, 'pressed')
# ('5', 6.705905814, 'released')
# ('Key.caps_lock', 6.914423135, 'pressed')
# ('Key.caps_lock', 6.914436281, 'released')
# ('R', 6.975946657, 'pressed')
# ('Key.caps_lock', 7.058275424, 'pressed')
# ('Key.caps_lock', 7.058286548, 'released')
# ('r', 7.071794022, 'released')
# ('o', 7.199706077, 'pressed')
# ('o', 7.271850229, 'released')
# ('a', 7.275784958, 'pressed')
# ('a', 7.359963864, 'released')
# ('n', 7.400907001, 'pressed')
# ('l', 7.488967442, 'pressed')
# ('n', 7.505646079, 'released')
# ('l', 7.556940824, 'released')
# ('e', 7.599043663, 'pressed')
# ('e', 7.666915981, 'released')
# ('.', 8.445887082, 'pressed')
# ('.', 8.549686522, 'released')
# ('t', 8.611853611, 'pressed')
# ('t', 8.687777589, 'released')
# ('i', 8.727764754, 'pressed')
# ('i', 8.795746826, 'released')
# ('e', 8.803867154, 'pressed')
# ('e', 8.879887331, 'released')
# ('5', 8.999708821, 'pressed')
# ('5', 9.075802728, 'released')
# ('Key.caps_lock', 9.292497324, 'pressed')
# ('Key.caps_lock', 9.292514352, 'released')
# ('R', 9.349633844, 'pressed')
# ('Key.caps_lock', 9.424164771, 'pressed')
# ('Key.caps_lock', 9.424175898, 'released')
# ('r', 9.429159585, 'released')
# ('o', 9.544680083, 'pressed')
# ('a', 9.612835759, 'pressed')
# ('o', 9.61664871, 'released')
# ('a', 9.692839427, 'released')
# ('n', 9.746738091, 'pressed')
# ('l', 9.826728044, 'pressed')
# ('n', 9.850545787, 'released')
# ('l', 9.90300581, 'released')
# ('e', 9.950075828, 'pressed')
# ('e', 10.017196493, 'released')
# ('.', 10.895693961, 'pressed')
# ('.', 10.98373788, 'released')
# ('t', 11.050888287, 'pressed')
# ('t', 11.130674129, 'released')
# ('i', 11.171574765, 'pressed')
# ('i', 11.239631535, 'released')
# ('e', 11.255721896, 'pressed')
# ('e', 11.327774242, 'released')
# ('5', 11.471938228, 'pressed')
# ('5', 11.555700407, 'released')
# ('Key.caps_lock', 11.787779093, 'pressed')
# ('Key.caps_lock', 11.787790159, 'released')
# ('R', 11.848383782, 'pressed')
# ('Key.caps_lock', 11.91862649, 'pressed')
# ('Key.caps_lock', 11.918671495, 'released')
# ('r', 11.932593349, 'released')
# ('o', 12.004790087, 'pressed')
# ('o', 12.080667638, 'released')
# ('a', 12.108617921, 'pressed')
# ('a', 12.176653505, 'released')
# ('n', 12.198694268, 'pressed')
# ('l', 12.282672825, 'pressed')
# ('n', 12.306530101, 'released')
# ('l', 12.354674083, 'released')
# ('e', 12.3755941, 'pressed')
# ('e', 12.455645282, 'released')
# ('.', 13.25988524, 'pressed')
# ('.', 13.371432875, 'released')
# ('t', 13.454502712, 'pressed')
# ('t', 13.526452892, 'released')
# ('i', 13.55449457, 'pressed')
# ('i', 13.618593339, 'released')
# ('e', 13.634493603, 'pressed')
# ('e', 13.70658839, 'released')
# ('5', 13.841576821, 'pressed')
# ('5', 13.921616671, 'released')
# ('Key.caps_lock', 14.125956718, 'pressed')
# ('Key.caps_lock', 14.125966637, 'released')
# ('R', 14.199541702, 'pressed')
# ('Key.caps_lock', 14.270099543, 'pressed')
# ('Key.caps_lock', 14.270116489, 'released')
# ('r', 14.271589176, 'released')
# ('o', 14.402321665, 'pressed')
# ('a', 14.454528485, 'pressed')
# ('o', 14.478653442, 'released')
# ('a', 14.538466589, 'released')
# ('n', 14.597432685, 'pressed')
# ('l', 14.673575384, 'pressed')
# ('n', 14.693173044, 'released')
# ('l', 14.745801357, 'released')
# ('e', 14.76540465, 'pressed')
# ('e', 14.833687932, 'released')
# ('.', 15.765532084, 'pressed')
# ('.', 15.857469285, 'released')
# ('t', 15.941526744, 'pressed')
# ('t', 16.009338113, 'released')
# ('i', 16.033341445, 'pressed')
# ('i', 16.093240918, 'released')
# ('e', 16.121331388, 'pressed')
# ('e', 16.197351633, 'released')
# ('5', 16.318406336, 'pressed')
# ('5', 16.390453158, 'released')
# ('Key.caps_lock', 16.608453254, 'pressed')
# ('Key.caps_lock', 16.608515339, 'released')
# ('R', 16.677421998, 'pressed')
# ('R', 16.749239315, 'released')
# ('Key.caps_lock', 16.763819699, 'pressed')
# ('Key.caps_lock', 16.763832355, 'released')
# ('o', 16.910369892, 'pressed')
# ('a', 16.944975959, 'pressed')
# ('o', 16.997108859, 'released')
# ('a', 17.013380482, 'released')
# ('n', 17.179316474, 'pressed')
# ('l', 17.263414831, 'pressed')
# ('n', 17.280195863, 'released')
# ('l', 17.331297134, 'released')
# ('e', 17.339226152, 'pressed')
# ('e', 17.407424615, 'released')
# ('.', 18.276525364, 'pressed')
# ('.', 18.376379429, 'released')
# ('t', 18.480031678, 'pressed')
# ('t', 18.564385422, 'released')
# ('i', 18.58526389, 'pressed')
# ('i', 18.64928596, 'released')
# ('e', 18.679193393, 'pressed')
# ('e', 18.747253038, 'released')
# ('5', 18.873174587, 'pressed')
# ('5', 18.949255344, 'released')
# ('Key.caps_lock', 19.158741653, 'pressed')
# ('Key.caps_lock', 19.158756475, 'released')
# ('R', 19.212198383, 'pressed')
# ('Key.caps_lock', 19.291261568, 'pressed')
# ('Key.caps_lock', 19.291274228, 'released')
# ('r', 19.295718369, 'released')
# ('o', 19.460323961, 'pressed')
# ('o', 19.520782848, 'released')
# ('a', 20.039197202, 'pressed')
# ('a', 20.099067266, 'released')
# ('n', 20.156157381, 'pressed')
# ('l', 20.236208822, 'pressed')
# ('n', 20.249785522, 'released')
# ('e', 20.304110098, 'pressed')
# ('l', 20.317890029, 'released')
# ('e', 20.364160421, 'released')
# ('.', 21.233155197, 'pressed')
# ('.', 21.324998877, 'released')
# ('t', 21.417139436, 'pressed')
# ('t', 21.497156039, 'released')
# ('i', 21.530061679, 'pressed')
# ('i', 21.594117896, 'released')
# ('e', 21.615258304, 'pressed')
# ('e', 21.691054578, 'released')
# ('5', 21.830850442, 'pressed')
# ('5', 21.895262989, 'released')
# ('Key.caps_lock', 22.130249595, 'pressed')
# ('Key.caps_lock', 22.1302654, 'released')
# ('R', 22.186155911, 'pressed')
# ('Key.caps_lock', 22.272851587, 'pressed')
# ('Key.caps_lock', 22.272930696, 'released')
# ('r', 22.273140312, 'released')
# ('o', 22.409554053, 'pressed')
# ('o', 22.480003868, 'released')
# ('a', 22.49614316, 'pressed')
# ('a', 22.57603193, 'released')
# ('n', 22.625992106, 'pressed')
# ('l', 22.69409719, 'pressed')
# ('n', 22.717512268, 'released')
# ('l', 22.774259835, 'released')
# ('e', 22.804070816, 'pressed')
# ('e', 22.860064186, 'released')
# ('.', 23.691014346, 'pressed')
# ('.', 23.802969265, 'released')
# ('t', 23.91882597, 'pressed')
# ('t', 23.998976255, 'released')
# ('i', 24.028016782, 'pressed')
# ('i', 24.092038051, 'released')
# ('e', 24.149190577, 'pressed')
# ('e', 24.23704192, 'released')
# ('5', 24.352663724, 'pressed')
# ('5', 24.41702316, 'released')
# ('Key.caps_lock', 24.634474528, 'pressed')
# ('Key.caps_lock', 24.634532358, 'released')
# ('R', 24.679794659, 'pressed')
# ('Key.caps_lock', 24.762318763, 'pressed')
# ('Key.caps_lock', 24.762330554, 'released')
# ('r', 24.763927916, 'released')
# ('o', 24.893953488, 'pressed')
# ('o', 24.961720797, 'released')
# ('a', 24.965779935, 'pressed')
# ('a', 25.053961271, 'released')
# ('n', 25.101927388, 'pressed')
# ('l', 25.181880835, 'pressed')
# ('n', 25.205287628, 'released')
# ('l', 25.257944507, 'released')
# ('e', 25.305994365, 'pressed')
# ('e', 25.361972105, 'released')
# ('.', 3.804211877, 'pressed')
# ('.', 3.90030333, 'released')
# ('t', 3.97904545, 'pressed')
# ('t', 4.051115788, 'released')
# ('i', 4.09806051, 'pressed')
# ('i', 4.166022375, 'released')
# ('e', 4.178058755, 'pressed')
# ('e', 4.250261338, 'released')
# ('5', 4.393988665, 'pressed')
# ('5', 4.462000345, 'released')
# ('Key.caps_lock', 4.667308349, 'pressed')
# ('Key.caps_lock', 4.667318798, 'released')
# ('R', 4.741029456, 'pressed')
# ('Key.caps_lock', 4.820300369, 'pressed')
# ('Key.caps_lock', 4.820323727, 'released')
# ('r', 4.820543964, 'released')
# ('o', 4.975957413, 'pressed')
# ('o', 5.054136145, 'released')
# ('a', 5.080103743, 'pressed')
# ('a', 5.171954958, 'released')
# ('n', 5.187889246, 'pressed')
# ('l', 5.252018881, 'pressed')
# ('n', 5.275795921, 'released')
# ('l', 5.328136289, 'released')
# ('e', 5.369988504, 'pressed')
# ('e', 5.437550014, 'released')
# ('.', 6.289828409, 'pressed')
# ('.', 6.382004196, 'released')
# ('t', 6.536036123, 'pressed')
# ('t', 6.615866039, 'released')
# ('i', 6.634992026, 'pressed')
# ('i', 6.703003079, 'released')
# ('e', 6.719918014, 'pressed')
# ('e', 6.79997863, 'released')
# ('5', 6.940925886, 'pressed')
# ('5', 7.008807725, 'released')
# ('Key.caps_lock', 7.224853967, 'pressed')
# ('Key.caps_lock', 7.224874, 'released')
# ('R', 7.290997426, 'pressed')
# ('Key.caps_lock', 7.377787748, 'pressed')
# ('Key.caps_lock', 7.377800866, 'released')
# ('r', 7.378128345, 'released')
# ('o', 7.49491457, 'pressed')
# ('o', 7.570891679, 'released')
# ('a', 7.587052726, 'pressed')
# ('a', 7.663013939, 'released')
# ('n', 7.694953765, 'pressed')
# ('l', 7.758759795, 'pressed')
# ('n', 7.786602038, 'released')
# ('l', 7.846950058, 'released')
# ('e', 7.864011109, 'pressed')
# ('e', 7.939844797, 'released')
# ('.', 8.889918191, 'pressed')
# ('.', 8.981885695, 'released')
# ('t', 9.054231133, 'pressed')
# ('t', 9.134030736, 'released')
# ('i', 9.164707426, 'pressed')
# ('i', 9.236824562, 'released')
# ('e', 9.248795173, 'pressed')
# ('e', 9.325157987, 'released')
# ('5', 9.47480679, 'pressed')
# ('5', 9.539045076, 'released')
# ('Key.caps_lock', 9.746674119, 'pressed')
# ('Key.caps_lock', 9.74668163, 'released')
# ('R', 9.812762227, 'pressed')
# ('Key.caps_lock', 9.891877685, 'pressed')
# ('Key.caps_lock', 9.891890867, 'released')
# ('r', 9.896411274, 'released')
# ('o', 10.016185524, 'pressed')
# ('a', 10.083674366, 'pressed')
# ('o', 10.087607144, 'released')
# ('a', 10.167901339, 'released')
# ('n', 10.219771306, 'pressed')
# ('l', 10.291935829, 'pressed')
# ('n', 10.311757899, 'released')
# ('l', 10.375740003, 'released')
# ('e', 10.391876397, 'pressed')
# ('e', 10.463186157, 'released')
# ('.', 11.462777692, 'pressed')
# ('.', 11.554876868, 'released')
# ('t', 11.627627505, 'pressed')
# ('t', 11.695805805, 'released')
# ('i', 11.734754493, 'pressed')
# ('i', 11.806701864, 'released')
# ('e', 11.823639246, 'pressed')
# ('e', 11.899714978, 'released')
# ('5', 12.049100053, 'pressed')
# ('5', 12.121782482, 'released')
# ('Key.caps_lock', 12.331782282, 'pressed')
# ('Key.caps_lock', 12.331824764, 'released')
# ('R', 12.393669336, 'pressed')
# ('Key.caps_lock', 12.468319256, 'pressed')
# ('Key.caps_lock', 12.468330892, 'released')
# ('r', 12.485615379, 'released')
# ('o', 12.614617817, 'pressed')
# ('o', 12.682486436, 'released')
# ('a', 12.690618994, 'pressed')
# ('a', 12.774868365, 'released')
# ('n', 12.822627497, 'pressed')
# ('l', 12.890614483, 'pressed')
# ('n', 12.914153416, 'released')
# ('l', 12.970689883, 'released')
# ('e', 13.004923712, 'pressed')
# ('e', 13.072817301, 'released')
# ('.', 14.0554194, 'pressed')
# ('.', 14.143557747, 'released')
# ('t', 14.226627918, 'pressed')
# ('t', 14.261628756, 'released')
# ('i', 14.493707095, 'pressed')
# ('i', 14.557540931, 'released')
# ('e', 14.612614623, 'pressed')
# ('e', 14.68458267, 'released')
# ('5', 14.942700215, 'pressed')
# ('5', 14.970005682, 'released')
# ('Key.caps_lock', 15.237470959, 'pressed')
# ('Key.caps_lock', 15.237484075, 'released')
# ('R', 15.296607027, 'pressed')
# ('Key.caps_lock', 15.371000749, 'pressed')
# ('Key.caps_lock', 15.371058798, 'released')
# ('r', 15.379901527, 'released')
# ('o', 15.469308632, 'pressed')
# ('o', 15.553475962, 'released')
# ('a', 15.569686418, 'pressed')
# ('a', 15.653537252, 'released')
# ('n', 15.676249076, 'pressed')
# ('l', 15.748414372, 'pressed')
# ('n', 15.772932861, 'released')
# ('l', 15.832502572, 'released')
# ('e', 15.857512843, 'pressed')
# ('e', 15.929545369, 'released')
# ('.', 16.769387121, 'pressed')
# ('.', 16.865349622, 'released')
# ('t', 16.964609874, 'pressed')
# ('t', 17.032706848, 'released')
# ('i', 17.068135105, 'pressed')
# ('i', 17.140377731, 'released')
# ('e', 17.181234854, 'pressed')
# ('e', 17.265442798, 'released')
# ('5', 17.450314413, 'pressed')
# ('5', 17.522477599, 'released')
# ('Key.caps_lock', 17.767959192, 'pressed')
# ('Key.caps_lock', 17.767970672, 'released')
# ('R', 17.846002658, 'pressed')
# ('R', 17.950714301, 'released')
# ('Key.caps_lock', 17.952758339, 'pressed')
# ('Key.caps_lock', 17.95277379, 'released')
# ('o', 18.054348536, 'pressed')
# ('o', 18.13845106, 'released')
# ('a', 18.168417611, 'pressed')
# ('a', 18.260376684, 'released')
# ('n', 18.293198694, 'pressed')
# ('l', 18.377405108, 'pressed')
# ('n', 18.392770266, 'released')
# ('l', 18.445425427, 'released')
# ('e', 18.478221925, 'pressed')
# ('e', 18.554400885, 'released')
# ('.', 19.798402562, 'pressed')
# ('.', 19.889778062, 'released')
# ('t', 20.001135993, 'pressed')
# ('t', 20.065139935, 'released')
# ('i', 20.091347393, 'pressed')
# ('i', 20.163296643, 'released')
# ('e', 20.185175988, 'pressed')
# ('e', 20.261308575, 'released')
# ('5', 20.416613537, 'pressed')
# ('5', 20.481273381, 'released')
# ('Key.caps_lock', 20.688529841, 'pressed')
# ('Key.caps_lock', 20.688539902, 'released')
# ('R', 20.754301966, 'pressed')
# ('Key.caps_lock', 20.836944671, 'pressed')
# ('Key.caps_lock', 20.836960016, 'released')
# ('r', 20.837168849, 'released')
# ('o', 20.931321863, 'pressed')
# ('o', 21.007240424, 'released')
# ('a', 21.025177359, 'pressed')
# ('a', 21.105296233, 'released')
# ('n', 21.136989818, 'pressed')
# ('l', 21.216177163, 'pressed')
# ('n', 21.239936401, 'released')
# ('l', 21.29208021, 'released')
# ('e', 21.317190635, 'pressed')
# ('e', 21.393406124, 'released')
# ('.', 22.274128657, 'pressed')
# ('.', 22.366606299, 'released')
# ('t', 22.473338287, 'pressed')
# ('t', 22.537126992, 'released')
# ('i', 22.556290698, 'pressed')
# ('i', 22.628167149, 'released')
# ('e', 22.659887152, 'pressed')
# ('e', 22.74416074, 'released')
# ('5', 22.890398204, 'pressed')
# ('5', 22.962130769, 'released')
# ('Key.caps_lock', 23.19017557, 'pressed')
# ('Key.caps_lock', 23.190203025, 'released')
# ('R', 23.256898804, 'pressed')
# ('Key.caps_lock', 23.351786364, 'pressed')
# ('Key.caps_lock', 23.351801127, 'released')
# ('r', 23.352255352, 'released')
# ('o', 23.42059681, 'pressed')
# ('o', 23.501376441, 'released')
# ('a', 23.53716303, 'pressed')
# ('a', 23.612998836, 'released')
# ('n', 23.625232634, 'pressed')
# ('l', 23.704884201, 'pressed')
# ('n', 23.721619627, 'released')
# ('l', 23.776989315, 'released')
# ('e', 23.829024757, 'pressed')
# ('e', 23.893082258, 'released')
# ('.', 24.966029525, 'pressed')
# ('.', 25.049753034, 'released')
# ('t', 25.23495411, 'pressed')
# ('t', 25.310994358, 'released')
# ('i', 25.349952308, 'pressed')
# ('i', 25.40601157, 'released')
# ('e', 25.492932008, 'pressed')
# ('e', 25.553003711, 'released')
# ('5', 25.717335717, 'pressed')
# ('5', 25.777950205, 'released')
# ('Key.caps_lock', 25.982514137, 'pressed')
# ('Key.caps_lock', 25.982521045, 'released')
# ('R', 26.030944257, 'pressed')
# ('Key.caps_lock', 26.108944308, 'pressed')
# ('Key.caps_lock', 26.108959676, 'released')
# ('r', 26.109245516, 'released')
# ('o', 26.237951448, 'pressed')
# ('a', 26.318144077, 'pressed')
# ('o', 26.318258725, 'released')
# ('a', 26.406159978, 'released')
# ('n', 26.449963614, 'pressed')
# ('l', 26.521929661, 'pressed')
# ('n', 26.549274354, 'released')
# ('l', 26.60193036, 'released')
# ('e', 26.638844877, 'pressed')
# ('e', 26.71095705, 'released')
# ('.', 6.536593982, 'pressed')
# ('.', 6.612855908, 'released')
# ('t', 7.002701152, 'pressed')
# ('t', 7.070716271, 'released')
# ('i', 7.277856723, 'pressed')
# ('i', 7.337695679, 'released')
# ('e', 7.551730469, 'pressed')
# ('e', 7.611777078, 'released')
# ('5', 7.927725021, 'pressed')
# ('5', 7.991631451, 'released')
# ('Key.caps_lock', 8.414508413, 'pressed')
# ('Key.caps_lock', 8.414522355, 'released')
# ('R', 8.646699465, 'pressed')
# ('R', 8.714678449, 'released')
# ('Key.caps_lock', 8.896534197, 'pressed')
# ('Key.caps_lock', 8.896544589, 'released')
# ('o', 9.152520717, 'pressed')
# ('o', 9.224591091, 'released')
# ('a', 9.354570872, 'pressed')
# ('a', 9.434536645, 'released')
# ('n', 9.50644263, 'pressed')
# ('n', 9.57849377, 'released')
# ('l', 9.804507909, 'pressed')
# ('l', 9.868535319, 'released')
# ('e', 10.057611735, 'pressed')
# ('e', 10.133560761, 'released')
# ('.', 6.092324042, 'pressed')
# ('.', 6.15642625, 'released')
# ('t', 6.47641521, 'pressed')
# ('t', 6.54049901, 'released')
# ('i', 6.765585308, 'pressed')
# ('i', 6.821546276, 'released')
# ('e', 7.074256489, 'pressed')
# ('e', 7.134579437, 'released')
# ('5', 7.383349306, 'pressed')
# ('5', 7.443477362, 'released')
# ('Key.caps_lock', 7.888860038, 'pressed')
# ('Key.caps_lock', 7.88887346, 'released')
# ('R', 8.133356398, 'pressed')
# ('R', 8.197825639, 'released')
# ('Key.caps_lock', 8.342391729, 'pressed')
# ('Key.caps_lock', 8.342405558, 'released')
# ('o', 8.670810783, 'pressed')
# ('o', 8.743458353, 'released')
# ('a', 8.903156706, 'pressed')
# ('a', 8.987345835, 'released')
# ('n', 9.096474711, 'pressed')
# ('n', 9.164322032, 'released')
# ('l', 9.339459384, 'pressed')
# ('l', 9.403295951, 'released')
# ('e', 9.527219488, 'pressed')
# ('e', 9.599263969, 'released')
# ('.', 11.030487055, 'pressed')
# ('.', 11.110158429, 'released')
# ('t', 11.397384389, 'pressed')
# ('t', 11.457388764, 'released')
# ('i', 11.696488878, 'pressed')
# ('i', 11.735862392, 'released')
# ('e', 11.912390695, 'pressed')
# ('e', 11.968236549, 'released')
# ('5', 12.280272724, 'pressed')
# ('5', 12.340210102, 'released')
# ('Key.caps_lock', 12.677683366, 'pressed')
# ('Key.caps_lock', 12.677695177, 'released')
# ('R', 12.862146827, 'pressed')
# ('R', 12.930326891, 'released')
# ('Key.caps_lock', 13.062054821, 'pressed')
# ('Key.caps_lock', 13.06206633, 'released')
# ('o', 13.275675742, 'pressed')
# ('o', 13.331568466, 'released')
# ('a', 13.472760917, 'pressed')
# ('a', 13.545231324, 'released')
# ('n', 13.63212228, 'pressed')
# ('n', 13.696097646, 'released')
# ('l', 13.86181462, 'pressed')
# ('l', 13.930029021, 'released')
# ('e', 14.032967584, 'pressed')
# ('e', 14.105192773, 'released')
# ('.', 15.380961869, 'pressed')
# ('.', 15.46457431, 'released')
# ('t', 15.710982294, 'pressed')
# ('t', 15.771078329, 'released')
# ('i', 15.921978424, 'pressed')
# ('i', 15.989991016, 'released')
# ('e', 16.140688644, 'pressed')
# ('e', 16.213165174, 'released')
# ('5', 16.477979223, 'pressed')
# ('5', 16.545915684, 'released')
# ('Key.caps_lock', 16.829415567, 'pressed')
# ('Key.caps_lock', 16.829428596, 'released')
# ('R', 16.995595179, 'pressed')
# ('R', 17.056017706, 'released')
# ('Key.caps_lock', 17.228254395, 'pressed')
# ('Key.caps_lock', 17.228266369, 'released')
# ('o', 17.423896975, 'pressed')
# ('o', 17.507937285, 'released')
# ('a', 17.563007486, 'pressed')
# ('a', 17.642940823, 'released')
# ('n', 17.684955906, 'pressed')
# ('l', 17.760964025, 'pressed')
# ('n', 17.78243011, 'released')
# ('l', 17.852934268, 'released')
# ('e', 18.364875274, 'pressed')
# ('e', 18.436939349, 'released')
# ('.', 20.015880958, 'pressed')
# ('.', 20.095794131, 'released')
# ('t', 20.418725565, 'pressed')
# ('t', 20.482659851, 'released')
# ('i', 20.650768802, 'pressed')
# ('i', 20.714859955, 'released')
# ('e', 20.872215587, 'pressed')
# ('e', 20.932883981, 'released')
# ('5', 21.224829525, 'pressed')
# ('5', 21.296647218, 'released')
# ('Key.caps_lock', 21.579684784, 'pressed')
# ('Key.caps_lock', 21.579700895, 'released')
# ('R', 21.73280242, 'pressed')
# ('R', 21.804882781, 'released')
# ('Key.caps_lock', 21.924187892, 'pressed')
# ('Key.caps_lock', 21.924200245, 'released')
# ('o', 22.107510503, 'pressed')
# ('o', 22.191895491, 'released')
# ('a', 22.492577621, 'pressed')
# ('a', 22.56493092, 'released')
# ('n', 22.674781069, 'pressed')
# ('n', 22.758696943, 'released')
# ('l', 22.79362483, 'pressed')
# ('l', 22.873232815, 'released')
# ('e', 23.244630172, 'pressed')
# ('e', 23.32066217, 'released')
# ('.', 24.866532465, 'pressed')
# ('.', 24.950478236, 'released')
# ('t', 25.304547108, 'pressed')
# ('t', 25.372586403, 'released')
# ('i', 25.504556617, 'pressed')
# ('i', 25.576632882, 'released')
# ('e', 25.72051401, 'pressed')
# ('e', 25.79254663, 'released')
# ('5', 26.038600006, 'pressed')
# ('5', 26.106669346, 'released')
# ('Key.caps_lock', 26.434847842, 'pressed')
# ('Key.caps_lock', 26.43486046, 'released')
# ('R', 26.671434219, 'pressed')
# ('R', 26.743566479, 'released')
# ('Key.caps_lock', 26.896272951, 'pressed')
# ('Key.caps_lock', 26.896281784, 'released')
# ('o', 27.135497502, 'pressed')
# ('o', 27.21141148, 'released')
# ('a', 27.36843666, 'pressed')
# ('a', 27.444437033, 'released')
# ('n', 27.564247781, 'pressed')
# ('n', 27.628445622, 'released')
# ('l', 28.020435843, 'pressed')
# ('l', 28.084481718, 'released')
# ('e', 28.251351743, 'pressed')
# ('e', 28.327307377, 'released')
# ('.', 29.904294547, 'pressed')
# ('.', 29.97238303, 'released')
# ('t', 30.447487087, 'pressed')
# ('t', 30.50314911, 'released')
# ('i', 30.688056381, 'pressed')
# ('i', 30.753172628, 'released')
# ('e', 31.077264919, 'pressed')
# ('e', 31.137737807, 'released')
# ('5', 31.52297933, 'pressed')
# ('5', 31.587146446, 'released')
# ('Key.caps_lock', 32.041393457, 'pressed')
# ('Key.caps_lock', 32.041404389, 'released')
# ('R', 32.379157041, 'pressed')
# ('R', 32.447251392, 'released')
# ('Key.caps_lock', 32.687751257, 'pressed')
# ('Key.caps_lock', 32.687764819, 'released')
# ('o', 33.172265837, 'pressed')
# ('o', 33.240164644, 'released')
# ('a', 33.445935659, 'pressed')
# ('a', 33.514195908, 'released')
# ('n', 33.745059224, 'pressed')
# ('n', 33.801138777, 'released')
# ('l', 34.160902218, 'pressed')
# ('l', 34.220939124, 'released')
# ('e', 34.438048376, 'pressed')
# ('e', 34.509980615, 'released')
# ('.', 36.138057373, 'pressed')
# ('.', 36.2019821, 'released')
# ('t', 36.673877815, 'pressed')
# ('t', 36.733903425, 'released')
# ('i', 36.965689827, 'pressed')
# ('i', 37.033889076, 'released')
# ('e', 37.223102624, 'pressed')
# ('e', 37.258645965, 'released')
# ('5', 37.559820201, 'pressed')
# ('5', 37.63198464, 'released')
# ('Key.caps_lock', 38.113556436, 'pressed')
# ('Key.caps_lock', 38.113569094, 'released')
# ('R', 38.34385705, 'pressed')
# ('R', 38.411720951, 'released')
# ('Key.caps_lock', 38.533510274, 'pressed')
# ('Key.caps_lock', 38.533522325, 'released')
# ('o', 38.72279265, 'pressed')
# ('o', 38.782854275, 'released')
# ('a', 39.149798066, 'pressed')
# ('a', 39.229777555, 'released')
# ('n', 39.412646163, 'pressed')
# ('n', 39.46882054, 'released')
# ('l', 39.813823331, 'pressed')
# ('l', 39.874055017, 'released')
# ('e', 40.103768243, 'pressed')
# ('e', 40.163637137, 'released')
# ('.', 41.70977285, 'pressed')
# ('.', 41.777709152, 'released')
# ('t', 42.220586508, 'pressed')
# ('t', 42.288621963, 'released')
# ('i', 42.452525039, 'pressed')
# ('i', 42.520661986, 'released')
# ('e', 42.690369938, 'pressed')
# ('e', 42.754623429, 'released')
# ('5', 43.095512319, 'pressed')
# ('5', 43.159584158, 'released')
# ('Key.caps_lock', 43.482721192, 'pressed')
# ('Key.caps_lock', 43.482733234, 'released')
# ('R', 43.703394263, 'pressed')
# ('R', 43.771529832, 'released')
# ('Key.caps_lock', 43.922449737, 'pressed')
# ('Key.caps_lock', 43.922461355, 'released')
# ('o', 44.130397102, 'pressed')
# ('o', 44.194520171, 'released')
# ('a', 44.664443091, 'pressed')
# ('a', 44.748482454, 'released')
# ('n', 44.986601072, 'pressed')
# ('n', 45.054405797, 'released')
# ('l', 45.300389073, 'pressed')
# ('l', 45.372566518, 'released')
# ('e', 45.537057862, 'pressed')
# ('e', 45.601568442, 'released')
# ('.', 47.203309927, 'pressed')
# ('.', 47.267332913, 'released')
# ('t', 47.598241176, 'pressed')
# ('t', 47.662321204, 'released')
# ('i', 47.883451406, 'pressed')
# ('i', 47.947337206, 'released')
# ('e', 48.097373238, 'pressed')
# ('e', 48.161475411, 'released')
# ('5', 48.529227057, 'pressed')
# ('5', 48.601338953, 'released')
# ('Key.caps_lock', 48.932475845, 'pressed')
# ('Key.caps_lock', 48.932501023, 'released')
# ('R', 49.148252629, 'pressed')
# ('R', 49.220202565, 'released')
# ('Key.caps_lock', 49.423508945, 'pressed')
# ('Key.caps_lock', 49.423515685, 'released')
# ('o', 49.784288129, 'pressed')
# ('o', 49.860310146, 'released')
# ('a', 50.04619242, 'pressed')
# ('a', 50.109248283, 'released')
# ('n', 50.191206449, 'pressed')
# ('n', 50.243320792, 'released')
# ('l', 50.63939104, 'pressed')
# ('l', 50.703336232, 'released')
# ('e', 50.972101698, 'pressed')
# ('e', 51.040262547, 'released')
# ('.', 8.098233426, 'pressed')
# ('.', 8.174240969, 'released')
# ('t', 8.595244997, 'pressed')
# ('t', 8.659283578, 'released')
# ('i', 8.96733097, 'pressed')
# ('i', 9.031313165, 'released')
# ('e', 9.24623179, 'pressed')
# ('e', 9.314356479, 'released')
# ('5', 9.653252587, 'pressed')
# ('5', 9.720930254, 'released')
# ('Key.caps_lock', 10.073260971, 'pressed')
# ('Key.caps_lock', 10.073272782, 'released')
# ('R', 10.325938189, 'pressed')
# ('R', 10.390190687, 'released')
# ('Key.caps_lock', 10.547895552, 'pressed')
# ('Key.caps_lock', 10.547906723, 'released')
# ('o', 10.857222447, 'pressed')
# ('o', 10.933061311, 'released')
# ('a', 11.116011707, 'pressed')
# ('a', 11.194970949, 'released')
# ('n', 11.302013467, 'pressed')
# ('n', 11.358142808, 'released')
# ('l', 11.770130027, 'pressed')
# ('l', 11.842125295, 'released')
# ('e', 12.051122454, 'pressed')
# ('e', 12.134964211, 'released')
# ('.', 13.704019204, 'pressed')
# ('.', 13.779905679, 'released')
# ('t', 14.203013483, 'pressed')
# ('t', 14.258899603, 'released')
# ('i', 14.555033745, 'pressed')
# ('i', 14.622997704, 'released')
# ('e', 14.885317122, 'pressed')
# ('e', 14.945912069, 'released')
# ('5', 15.280022552, 'pressed')
# ('5', 15.343892559, 'released')
# ('Key.caps_lock', 15.786054305, 'pressed')
# ('Key.caps_lock', 15.786065958, 'released')
# ('R', 16.027820655, 'pressed')
# ('R', 16.095686853, 'released')
# ('Key.caps_lock', 16.264881839, 'pressed')
# ('Key.caps_lock', 16.264903635, 'released')
# ('o', 16.538996646, 'pressed')
# ('o', 16.594873062, 'released')
# ('a', 16.791502873, 'pressed')
# ('a', 16.8678987, 'released')
# ('n', 17.042723195, 'pressed')
# ('n', 17.098668705, 'released')
# ('l', 17.535718847, 'pressed')
# ('l', 17.62012571, 'released')
# ('e', 17.864743564, 'pressed')
# ('e', 17.916859728, 'released')
# ('.', 19.677488301, 'pressed')
# ('.', 19.749641432, 'released')
# ('t', 20.303622828, 'pressed')
# ('t', 20.375643661, 'released')
# ('i', 20.64152494, 'pressed')
# ('i', 20.709639493, 'released')
# ('e', 20.969550755, 'pressed')
# ('e', 21.041599483, 'released')
# ('5', 21.386519585, 'pressed')
# ('5', 21.458622131, 'released')
# ('Key.caps_lock', 21.996733505, 'pressed')
# ('Key.caps_lock', 21.996745582, 'released')
# ('R', 22.208496006, 'pressed')
# ('R', 22.2804231, 'released')
# ('Key.caps_lock', 22.460199322, 'pressed')
# ('Key.caps_lock', 22.460208919, 'released')
# ('o', 22.757473082, 'pressed')
# ('o', 22.833384202, 'released')
# ('a', 23.049640513, 'pressed')
# ('a', 23.133359684, 'released')
# ('n', 23.291859812, 'pressed')
# ('n', 23.348486809, 'released')
# ('l', 23.671425963, 'pressed')
# ('l', 23.755527699, 'released')
# ('e', 23.91135619, 'pressed')
# ('e', 23.99142414, 'released')
# ('.', 25.893308178, 'pressed')
# ('.', 25.977332194, 'released')
# ('t', 26.459272808, 'pressed')
# ('t', 26.527303071, 'released')
# ('i', 26.831277614, 'pressed')
# ('i', 26.899306845, 'released')
# ('e', 27.155231644, 'pressed')
# ('e', 27.219342566, 'released')
# ('5', 27.692879023, 'pressed')
# ('5', 27.742220163, 'released')
# ('Key.caps_lock', 28.212117944, 'pressed')
# ('Key.caps_lock', 28.21212831, 'released')
# ('R', 28.500300372, 'pressed')
# ('R', 28.56828452, 'released')
# ('Key.caps_lock', 28.752291799, 'pressed')
# ('Key.caps_lock', 28.752301814, 'released')
# ('o', 29.315274792, 'pressed')
# ('o', 29.387053948, 'released')
# ('a', 29.662191155, 'pressed')
# ('a', 29.738182102, 'released')
# ('n', 29.932292178, 'pressed')
# ('n', 29.984107579, 'released')
# ('l', 30.303933816, 'pressed')
# ('l', 30.380149109, 'released')
# ('e', 30.593095351, 'pressed')
# ('e', 30.648968443, 'released')
# ('.', 32.385049242, 'pressed')
# ('.', 32.469039472, 'released')
# ('t', 32.88795395, 'pressed')
# ('t', 32.948115678, 'released')
# ('i', 33.316090288, 'pressed')
# ('i', 33.375803428, 'released')
# ('e', 33.628946169, 'pressed')
# ('e', 33.689049609, 'released')
# ('5', 33.981896045, 'pressed')
# ('5', 34.049955287, 'released')
# ('Key.caps_lock', 34.443261957, 'pressed')
# ('Key.caps_lock', 34.443273848, 'released')
# ('R', 34.651023168, 'pressed')
# ('R', 34.719079401, 'released')
# ('Key.caps_lock', 34.87644227, 'pressed')
# ('Key.caps_lock', 34.876454108, 'released')
# ('o', 35.225605397, 'pressed')
# ('o', 35.301942072, 'released')
# ('a', 35.489538389, 'pressed')
# ('a', 35.577886167, 'released')
# ('n', 35.732741131, 'pressed')
# ('n', 35.792857502, 'released')
# ('l', 36.167694966, 'pressed')
# ('l', 36.247802664, 'released')
# ('e', 36.369893019, 'pressed')
# ('e', 36.445832496, 'released')
# ('.', 38.129636519, 'pressed')
# ('.', 38.205691916, 'released')
# ('t', 38.59173883, 'pressed')
# ('t', 38.65183126, 'released')
# ('i', 38.903444662, 'pressed')
# ('i', 38.967689328, 'released')
# ('e', 39.293689523, 'pressed')
# ('e', 39.353610355, 'released')
# ('5', 39.639436722, 'pressed')
# ('5', 39.707286224, 'released')
# ('Key.caps_lock', 40.069706683, 'pressed')
# ('Key.caps_lock', 40.06972125, 'released')
# ('R', 40.258510791, 'pressed')
# ('R', 40.32646174, 'released')
# ('Key.caps_lock', 40.449912195, 'pressed')
# ('Key.caps_lock', 40.449922653, 'released')
# ('o', 40.826740366, 'pressed')
# ('o', 40.894596094, 'released')
# ('a', 41.134595896, 'pressed')
# ('a', 41.210724152, 'released')
# ('n', 41.336436013, 'pressed')
# ('n', 41.40053999, 'released')
# ('l', 41.648632778, 'pressed')
# ('l', 41.728532946, 'released')
# ('e', 41.892026608, 'pressed')
# ('e', 41.962413575, 'released')
# ('.', 43.556513591, 'pressed')
# ('.', 43.624452522, 'released')
# ('t', 44.060675229, 'pressed')
# ('t', 44.128236417, 'released')
# ('i', 44.354258692, 'pressed')
# ('i', 44.418441094, 'released')
# ('e', 44.772368236, 'pressed')
# ('e', 44.836386756, 'released')
# ('5', 45.189493967, 'pressed')
# ('5', 45.253311435, 'released')
# ('Key.caps_lock', 45.656580266, 'pressed')
# ('Key.caps_lock', 45.656594572, 'released')
# ('R', 45.9012618, 'pressed')
# ('R', 45.97315014, 'released')
# ('Key.caps_lock', 46.17401288, 'pressed')
# ('Key.caps_lock', 46.174023537, 'released')
# ('o', 46.527264834, 'pressed')
# ('o', 46.599287587, 'released')
# ('a', 46.774015288, 'pressed')
# ('a', 46.861246062, 'released')
# ('n', 46.963060649, 'pressed')
# ('n', 47.027267945, 'released')
# ('l', 47.299163984, 'pressed')
# ('l', 47.375246411, 'released')
# ('e', 47.5941897, 'pressed')
# ('e', 47.670221907, 'released')
# ('.', 49.378025841, 'pressed')
# ('.', 49.454156551, 'released')
# ('t', 50.009047288, 'pressed')
# ('t', 50.07307513, 'released')
# ('i', 50.353000448, 'pressed')
# ('i', 50.421021639, 'released')
# ('e', 50.655870519, 'pressed')
# ('e', 50.724048463, 'released')
# ('5', 51.007863349, 'pressed')
# ('5', 51.079851665, 'released')
# ('Key.caps_lock', 51.44449395, 'pressed')
# ('Key.caps_lock', 51.444522065, 'released')
# ('R', 51.657141012, 'pressed')
# ('R', 51.728985543, 'released')
# ('Key.caps_lock', 51.915094842, 'pressed')
# ('Key.caps_lock', 51.915109584, 'released')
# ('o', 52.323046378, 'pressed')
# ('o', 52.39099364, 'released')
# ('a', 52.664052569, 'pressed')
# ('a', 52.751983669, 'released')
# ('n', 52.942655528, 'pressed')
# ('n', 52.998862664, 'released')
# ('l', 53.331969119, 'pressed')
# ('l', 53.411892199, 'released')
# ('e', 53.589014801, 'pressed')
# ('e', 53.668945344, 'released')
# ('.', 55.277877537, 'pressed')
# ('.', 55.353869722, 'released')
# ('t', 55.743785578, 'pressed')
# ('t', 55.811775466, 'released')
# ('i', 55.997663771, 'pressed')
# ('i', 56.065789123, 'released')
# ('e', 56.336783842, 'pressed')
# ('e', 56.395771979, 'released')
# ('5', 56.800612277, 'pressed')
# ('5', 56.880655238, 'released')
# ('Key.caps_lock', 57.26731047, 'pressed')
# ('Key.caps_lock', 57.267364153, 'released')
# ('R', 57.464716587, 'pressed')
# ('R', 57.54090675, 'released')
# ('Key.caps_lock', 57.7598385, 'pressed')
# ('Key.caps_lock', 57.759859745, 'released')
# ('o', 58.096616204, 'pressed')
# ('o', 58.168573902, 'released')
# ('a', 58.419758234, 'pressed')
# ('a', 58.507650439, 'released')
# ('n', 58.67352949, 'pressed')
# ('n', 58.737613467, 'released')
# ('l', 59.025586278, 'pressed')
# ('l', 59.113544279, 'released')
# ('e', 59.305601604, 'pressed')
# ('e', 59.385691684, 'released')

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# Extract the following features from the data:
# a. Key hold time (total time that a key is held down)
# b. Keydown-Keydown time (time between pressing of consecutive keys)
# c. Keyup-Keydown time (time between the release of one key and the press of next key)
#
#
# ![features.png](attachment:features.png)

# %% [markdown]
# ### a. First finding key hold times for a given data row:

# %%
def key_hold_times(datarow):
    output = []
    
    # loop through all tuples in data row
    for i in range(len(datarow)):
        # find only pairs for keys that are pressed
        if datarow[i][2] == "pressed":
            current_char = datarow[i][0].lower()
            # start looking for other half of pair from next index onwards
            for j in range(i + 1, len(datarow)):
                next_char = datarow[j][0].lower()
                # if they match, record differences in time
                if next_char == current_char:
                    output.append(("hold_"+ current_char, float(datarow[j][1]) - float(datarow[i][1])))
                    break
                    
    return output

# %% [markdown]
# Loop and print differences in key hold times between different data samples to make sure that they are small

# %%
# first for akshay's data
hold0 = key_hold_times(akshay_data[0])

hold1 = key_hold_times(akshay_data[1])

hold2 = key_hold_times(akshay_data[2])

print("differences in hold times between sample 0 and sample 1 in Akshay's data")
for i in range(len(hold0)):
    print(hold0[i][0], np.abs(round(hold0[i][1] - hold1[i][1], 5)))
    
print("\ndifferences in hold times between sample 1 and sample 2 in Akshay's data")
for i in range(len(hold0)):
    print(hold1[i][0], np.abs(round(hold1[i][1] - hold2[i][1], 5)))
    
print()
    
# then for mummy's data
hold0 = key_hold_times(mummy_data[0])

hold1 = key_hold_times(mummy_data[1])

hold2 = key_hold_times(mummy_data[2])

print("differences in hold times between sample 0 and sample 1 in Mummy's data")
for i in range(len(hold0)):
    print(hold0[i][0], np.abs(round(hold0[i][1] - hold1[i][1], 5)))
    
print("\ndifferences in hold times between sample 1 and sample 2 in Mummy's data")
for i in range(len(hold0)):
    print(hold1[i][0], np.abs(round(hold1[i][1] - hold2[i][1], 5)))
# Out:
# differences in hold times between sample 0 and sample 1 in Akshay's data
# hold_. 0.012
# hold_t 0.0041
# hold_i 0.00833
# hold_e 0.00801
# hold_5 7e-05
# hold_key.caps_lock 0.0
# hold_r 0.02424
# hold_key.caps_lock 0.0
# hold_o 0.03309
# hold_a 0.01938
# hold_n 0.00071
# hold_l 0.01002
# hold_e 0.01616
#
# differences in hold times between sample 1 and sample 2 in Akshay's data
# hold_. 0.00386
# hold_t 0.00012
# hold_i 0.00382
# hold_e 0.012
# hold_5 0.00388
# hold_key.caps_lock 1e-05
# hold_r 0.01132
# hold_key.caps_lock 0.0
# hold_o 0.02083
# hold_a 0.00062
# hold_n 0.01138
# hold_l 0.00794
# hold_e 0.01592
#
# differences in hold times between sample 0 and sample 1 in Mummy's data
# hold_. 0.01216
# hold_t 0.00393
# hold_i 0.00388
# hold_e 0.00028
# hold_5 0.00378
# hold_key.caps_lock 0.0
# hold_r 0.00351
# hold_key.caps_lock 0.0
# hold_o 0.00058
# hold_a 0.00422
# hold_n 0.0042
# hold_l 0.00019
# hold_e 0.0039
#
# differences in hold times between sample 1 and sample 2 in Mummy's data
# hold_. 0.01557
# hold_t 0.00408
# hold_i 0.01659
# hold_e 0.00448
# hold_5 0.00019
# hold_key.caps_lock 0.0
# hold_r 0.00371
# hold_key.caps_lock 0.0
# hold_o 0.01675
# hold_a 0.01172
# hold_n 0.00387
# hold_l 0.00438
# hold_e 0.00018

# %% [markdown]
# Great, now we can confirm that hold times are a repeatable charactericstic of the way people type

# %% [markdown]
# ### b. Next finding keydown-keydown times for a given data row:

# %%
def keydown_times(datarow):
    output = []
    
    # loop through all tuples in data row and keep only those that are "pressed"
    pressed = [x for x in datarow if x[2] == "pressed"]
    
    # find time between keydown of current key and keydown of next key
    for i in range(len(pressed) - 1):
        output.append(("dd_" + pressed[i][0] + pressed[i + 1][0], pressed[i + 1][1] - pressed[i][1]))
        
    return output

# %% [markdown]
# Loop and print differences in keydown-keydown times between different data samples to make sure that they are small

# %%
# first for akshay's data
keydown0 = keydown_times(akshay_data[0])

keydown1 = keydown_times(akshay_data[1])

keydown2 = keydown_times(akshay_data[2])

print("differences in keydown-keydown times between sample 0 and sample 1 in Akshay's data")
for i in range(len(keydown0)):
    print(keydown0[i][0], np.abs(round(keydown0[i][1] - keydown1[i][1], 5)))
    
print("\ndifferences in keydown-keydown times between sample 1 and sample 2 in Mummy's")
for i in range(len(keydown0)):
    print(keydown1[i][0], np.abs(round(keydown1[i][1] - keydown2[i][1], 5)))
    
print()

# first for mummy's data
keydown0 = keydown_times(mummy_data[0])

keydown1 = keydown_times(mummy_data[1])

keydown2 = keydown_times(mummy_data[2])

print("differences in keydown-keydown times between sample 0 and sample 1 in Akshay's")
for i in range(len(keydown0)):
    print(keydown0[i][0], np.abs(round(keydown0[i][1] - keydown1[i][1], 5)))
    
print("\ndifferences in keydown-keydown times between sample 1 and sample 2 in Mummy's")
for i in range(len(keydown0)):
    print(keydown1[i][0], np.abs(round(keydown1[i][1] - keydown2[i][1], 5)))
# Out:
# differences in keydown-keydown times between sample 0 and sample 1 in Akshay's data
# dd_.t 0.01399
# dd_ti 0.01825
# dd_ie 0.01025
# dd_e5 0.22685
# dd_5Key.caps_lock 0.0365
# dd_Key.caps_lockR 0.00855
# dd_RKey.caps_lock 0.02839
# dd_Key.caps_locko 0.02642
# dd_oa 0.0633
# dd_an 0.01954
# dd_nl 0.00013
# dd_le 0.01596
#
# differences in keydown-keydown times between sample 1 and sample 2 in Mummy's
# dd_.t 0.00107
# dd_ti 0.00999
# dd_ie 0.01812
# dd_e5 0.09201
# dd_5Key.caps_lock 0.02943
# dd_Key.caps_lockR 0.02339
# dd_RKey.caps_lock 0.01142
# dd_Key.caps_locko 0.07128
# dd_oa 0.03514
# dd_an 0.02603
# dd_nl 0.01945
# dd_le 0.00387
#
# differences in keydown-keydown times between sample 0 and sample 1 in Akshay's
# dd_.t 0.08202
# dd_ti 0.01401
# dd_ie 0.0348
# dd_e5 0.0669
# dd_5Key.caps_lock 0.01873
# dd_Key.caps_lockR 0.01231
# dd_RKey.caps_lock 0.0408
# dd_Key.caps_locko 0.07243
# dd_oa 0.0303
# dd_an 0.04145
# dd_nl 0.05508
# dd_le 0.06534
#
# differences in keydown-keydown times between sample 1 and sample 2 in Mummy's
# dd_.t 0.01719
# dd_ti 0.00993
# dd_ie 0.09277
# dd_e5 0.05879
# dd_5Key.caps_lock 0.1081
# dd_Key.caps_lockR 0.06003
# dd_RKey.caps_lock 0.00913
# dd_Key.caps_locko 0.1148
# dd_oa 0.03526
# dd_an 0.03396
# dd_nl 0.01329
# dd_le 0.01661

# %% [markdown]
# Awesome, now we can confirm that keydown-keydown times are a repeatable charactericstic of the way people type

# %% [markdown]
# ### c. Finally finding keyup-keydown times for a given data row:

# %%
# def keyup_keydown_times(datarow):
#     output = []
    
#     # loop through all tuples in data row and keep only pairs that are consectutively "released" then "pressed"
#     up_down = []
    
#     for i in range(len(datarow) - 1):
#         if datarow[i][2] == "released" and datarow[i+1][2] == "pressed":
#             up_down.append(datarow[i])
#             up_down.append(datarow[i+1])
            
#     # find time between keyup of current key and keydown of next key
#     for i in range(len(up_down) - 1):
#         output.append(("ud_" + up_down[i][0] + up_down[i + 1][0], up_down[i + 1][1] - up_down[i][1]))    
    
#     return output

# keyup_keydown_times(akshay_data[3])

# %% [markdown]
# Loop and print differences in keyup-keydown times between different data samples to make sure that they are small

# %%
# keyupdown0 = keyup_keydown_times(data[0])

# keyupdown1 = keyup_keydown_times(data[1])

# keyupdown2 = keyup_keydown_times(data[2])

# keyupdown3 = keyup_keydown_times(data[3])

# print([print(x) for x in keyupdown2])

# print("\n\n")

# print([print(x) for x in keyupdown3])

# # print("differences in keydown-keydown times between sample 0 and sample 1")
# # for i in range(len(keyupdown0)):
# #     print(keyupdown0[i][0], np.abs(round(keyupdown0[i][1] - keyupdown1[i][1], 5)))
    
# # print("\ndifferences in keydown-keydown times between sample 1 and sample 2")
# # for i in range(len(keyupdown0)):
# #     print(keyupdown1[i][0], np.abs(round(keyupdown1[i][1] - keyupdown2[i][1], 5)))

# %% [markdown]
# ### Putting it all together and extracting features for all rows in data:

# %%
# first for akshay's data
# extract features from all data rows and store in tupled_data[]
tupled_data = [] # data with descriptions

# loop through all rows in data
for row in akshay_data:
    # extract features
    hold = key_hold_times(row)
    keydown = keydown_times(row)

    # store features in single list
    tupled_data.append(hold + keydown)
    
# final list of lists that will be inputted into a pandas dataframe
# stripped of feature descriptions
akshay_input_data = []

for row in tupled_data:
    new_row = []
    for item in row:
        new_row += [item[1]]
            
    akshay_input_data += [new_row]
    
# then for mummy's data
# extract features from all data rows and store in tupled_data[]
tupled_data = [] # data with descriptions

# loop through all rows in data
for row in mummy_data:
    # extract features
    hold = key_hold_times(row)
    keydown = keydown_times(row)

    # store features in single list
    tupled_data.append(hold + keydown)
    
# final list of lists that will be inputted into a pandas dataframe
# stripped of feature descriptions
mummy_input_data = []

for row in tupled_data:
    new_row = []
    for item in row:
        new_row += [item[1]]
            
    mummy_input_data += [new_row]

# %% [markdown]
# Keep track of feature names of model in features[]

# %%
features = [tupled_data[0][x][0] for x in range(len(tupled_data[0]))]
# add label for classification
features += ["akshay?"]

print("model's features are:\n", features)
# Out:
# model's features are:
#  ['hold_.', 'hold_t', 'hold_i', 'hold_e', 'hold_5', 'hold_key.caps_lock', 'hold_r', 'hold_key.caps_lock', 'hold_o', 'hold_a', 'hold_n', 'hold_l', 'hold_e', 'dd_.t', 'dd_ti', 'dd_ie', 'dd_e5', 'dd_5Key.caps_lock', 'dd_Key.caps_lockR', 'dd_RKey.caps_lock', 'dd_Key.caps_locko', 'dd_oa', 'dd_an', 'dd_nl', 'dd_le', 'akshay?']

# %% [markdown]
# ### Label data by person who typed it

# %%
for row in akshay_input_data:
    row += [1]
    
for row in mummy_input_data:
    row += [0]

# %% [markdown]
# # 3. Loading data into Pandas dataframe

# %%
# combine input lists and then create a dataframe from them
input_data = akshay_input_data + mummy_input_data

print(len(input_data))

df = pd.DataFrame(input_data)
# Out:
# 41

# %% [markdown]
# Let's add feature names as columns and see what the first few rows look like

# %%
df.columns = features

df.head()
# Out:
#      hold_.    hold_t    hold_i    hold_e    hold_5  hold_key.caps_lock  \
# 0  0.112423  0.071869  0.068243  0.068043  0.071803            0.000012
# 1  0.100422  0.075966  0.059916  0.076050  0.071875            0.000007
# 2  0.096557  0.075849  0.056091  0.064054  0.067992            0.000013
# 3  0.104163  0.072020  0.060119  0.068060  0.075876            0.000009
# 4  0.092102  0.076233  0.056006  0.072246  0.072044            0.000010
#
#      hold_r  hold_key.caps_lock    hold_o    hold_a  ...     dd_e5  \
# 0  0.063379            0.000012  0.108072  0.076095  ...  0.192158
# 1  0.087623            0.000012  0.074978  0.095479  ...  0.419010
# 2  0.098940            0.000014  0.095808  0.096097  ...  0.327002
# 3  0.063919            0.000006  0.067999  0.096095  ...  0.211005
# 4  0.091873            0.000012  0.079911  0.088521  ...  0.201838
#
#    dd_5Key.caps_lock  dd_Key.caps_lockR  dd_RKey.caps_lock  dd_Key.caps_locko  \
# 0           0.280431           0.081338           0.058928           0.181955
# 1           0.316935           0.089889           0.087317           0.155538
# 2           0.287505           0.066500           0.098738           0.084260
# 3           0.287728           0.056666           0.070927           0.117680
# 4           0.272471           0.054487           0.082018           0.106111
#
#       dd_oa     dd_an     dd_nl     dd_le  akshay?
# 0  0.120096  0.150098  0.079997  0.084038        1
# 1  0.056795  0.130554  0.079863  0.099999        1
# 2  0.091933  0.156586  0.060410  0.103868        1
# 3  0.071932  0.126244  0.079796  0.083964        1
# 4  0.083815  0.123122  0.080226  0.099094        1
#
# [5 rows x 26 columns]

# %% [markdown]
# Double check that columns have the correct datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   hold_.              41 non-null     float64
#  1   hold_t              41 non-null     float64
#  2   hold_i              41 non-null     float64
#  3   hold_e              41 non-null     float64
#  4   hold_5              41 non-null     float64
#  5   hold_key.caps_lock  41 non-null     float64
#  6   hold_r              41 non-null     float64
#  7   hold_key.caps_lock  41 non-null     float64
#  8   hold_o              41 non-null     float64
#  9   hold_a              41 non-null     float64
#  10  hold_n              41 non-null     float64
#  11  hold_l              41 non-null     float64
#  12  hold_e              41 non-null     float64
#  13  dd_.t               41 non-null     float64
#  14  dd_ti               41 non-null     float64
#  15  dd_ie               41 non-null     float64
#  16  dd_e5               41 non-null     float64
#  17  dd_5Key.caps_lock   41 non-null     float64
#  18  dd_Key.caps_lockR   41 non-null     float64
#  19  dd_RKey.caps_lock   41 non-null     float64
#  20  dd_Key.caps_locko   41 non-null     float64
#  21  dd_oa               41 non-null     float64
#  22  dd_an               41 non-null     float64
#  23  dd_nl               41 non-null     float64
#  24  dd_le               41 non-null     float64
#  25  akshay?             41 non-null     int64
# dtypes: float64(25), int64(1)
# memory usage: 8.5 KB
